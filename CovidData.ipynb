# %%
# Dependencies
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import pandas as pd
import numpy as np
from scipy.stats import linregress
from scipy.stats import stats
# %matplotlib inline


# Import API key
from api_keys import g_key

# %%
# Convert dataset from below link into DataFrame
#  https://www.kaggle.com/datasets/georgesaavedra/covid19-dataset

# Load and Read csv file
load_covid_data = 'input_data/owid-covid-data.csv'
covid_world = pd.read_csv(load_covid_data)
covid_world
# Out:
#        iso_code continent           location        date  total_cases  \
# 0           SGP      Asia          Singapore  23/01/2020          1.0
# 1           SGP      Asia          Singapore  24/01/2020          3.0
# 2           SGP      Asia          Singapore  25/01/2020          3.0
# 3           SGP      Asia          Singapore  26/01/2020          4.0
# 4           SGP      Asia          Singapore  27/01/2020          5.0
# ...         ...       ...                ...         ...          ...
# 153816      WLF   Oceania  Wallis and Futuna  01/03/2022        454.0
# 153817      WLF   Oceania  Wallis and Futuna  02/03/2022        454.0
# 153818      WLF   Oceania  Wallis and Futuna  03/03/2022        454.0
# 153819      WLF   Oceania  Wallis and Futuna  04/03/2022        454.0
# 153820      WLF   Oceania  Wallis and Futuna  05/03/2022        454.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0             1.0                 NaN           NaN         NaN
# 1             2.0                 NaN           NaN         NaN
# 2             0.0                 NaN           NaN         NaN
# 3             1.0                 NaN           NaN         NaN
# 4             1.0                 NaN           NaN         NaN
# ...           ...                 ...           ...         ...
# 153816        0.0                 0.0           7.0         0.0
# 153817        0.0                 0.0           7.0         0.0
# 153818        0.0                 0.0           7.0         0.0
# 153819        0.0                 0.0           7.0         0.0
# 153820        0.0                 0.0           7.0         0.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 0                       NaN  ...             5.2          28.3
# 1                       NaN  ...             5.2          28.3
# 2                       NaN  ...             5.2          28.3
# 3                       NaN  ...             5.2          28.3
# 4                       NaN  ...             5.2          28.3
# ...                     ...  ...             ...           ...
# 153816                  0.0  ...             NaN           NaN
# 153817                  0.0  ...             NaN           NaN
# 153818                  0.0  ...             NaN           NaN
# 153819                  0.0  ...             NaN           NaN
# 153820                  0.0  ...             NaN           NaN
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                          NaN                         2.4            83.62
# 1                          NaN                         2.4            83.62
# 2                          NaN                         2.4            83.62
# 3                          NaN                         2.4            83.62
# 4                          NaN                         2.4            83.62
# ...                        ...                         ...              ...
# 153816                     NaN                         NaN            79.94
# 153817                     NaN                         NaN            79.94
# 153818                     NaN                         NaN            79.94
# 153819                     NaN                         NaN            79.94
# 153820                     NaN                         NaN            79.94
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 0                         0.938                                   NaN
# 1                         0.938                                   NaN
# 2                         0.938                                   NaN
# 3                         0.938                                   NaN
# 4                         0.938                                   NaN
# ...                         ...                                   ...
# 153816                      NaN                                   NaN
# 153817                      NaN                                   NaN
# 153818                      NaN                                   NaN
# 153819                      NaN                                   NaN
# 153820                      NaN                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 153816                          NaN               NaN
# 153817                          NaN               NaN
# 153818                          NaN               NaN
# 153819                          NaN               NaN
# 153820                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 153816                                      NaN
# 153817                                      NaN
# 153818                                      NaN
# 153819                                      NaN
# 153820                                      NaN
#
# [153821 rows x 67 columns]

# %%
# Dropping duplicates, keeping only latest date/update
covid_world['date'] = pd.to_datetime(covid_world['date'])


covid_world = covid_world.drop_duplicates(subset =['location'], keep='last')
covid_world
# Out:
#        iso_code continent           location       date  total_cases  \
# 772         SGP      Asia          Singapore 2022-05-03     819663.0
# 1545        HKG      Asia          Hong Kong 2022-05-03     440609.0
# 2277        GIB    Europe          Gibraltar 2022-05-03      15609.0
# 3018        BHR      Asia            Bahrain 2022-05-03     525171.0
# 3746        MDV      Asia           Maldives 2022-05-03     172270.0
# ...         ...       ...                ...        ...          ...
# 151693      SYR      Asia              Syria 2022-05-03      54963.0
# 151807      TKL   Oceania            Tokelau 2021-12-10          NaN
# 152587      TWN      Asia             Taiwan 2022-05-03      20797.0
# 153317      VAT    Europe            Vatican 2022-05-03         29.0
# 153820      WLF   Oceania  Wallis and Futuna 2022-05-03        454.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 772       16274.0           17573.000        1073.0         6.0
# 1545      37529.0           43093.429        1774.0       220.0
# 2277          NaN                 NaN         101.0         0.0
# 3018       1517.0            2254.429        1458.0         0.0
# 3746        323.0             446.000         297.0         0.0
# ...           ...                 ...           ...         ...
# 151693       69.0              83.286        3092.0         3.0
# 151807        NaN                 NaN           NaN         NaN
# 152587       80.0              60.571         853.0         0.0
# 153317        0.0               0.000           NaN         NaN
# 153820        0.0               0.000           7.0         0.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 772                  10.571  ...             5.2          28.3
# 1545                171.000  ...             NaN           NaN
# 2277                  0.000  ...             NaN           NaN
# 3018                  1.143  ...             5.8          37.6
# 3746                  0.143  ...             2.1          55.0
# ...                     ...  ...             ...           ...
# 151693                3.429  ...             NaN           NaN
# 151807                  NaN  ...             NaN           NaN
# 152587                0.000  ...             NaN           NaN
# 153317                  NaN  ...             NaN           NaN
# 153820                0.000  ...             NaN           NaN
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 772                        NaN                         2.4            83.62
# 1545                       NaN                         NaN            84.86
# 2277                       NaN                         NaN            79.93
# 3018                       NaN                         2.0            77.29
# 3746                    95.803                         NaN            78.92
# ...                        ...                         ...              ...
# 151693                  70.598                         1.5            72.70
# 151807                     NaN                         NaN            81.86
# 152587                     NaN                         NaN            80.46
# 153317                     NaN                         NaN            75.12
# 153820                     NaN                         NaN            79.94
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 772                       0.938                                   NaN
# 1545                      0.949                                   NaN
# 2277                        NaN                                   NaN
# 3018                      0.852                                   NaN
# 3746                      0.740                                   NaN
# ...                         ...                                   ...
# 151693                    0.567                                   NaN
# 151807                      NaN                                   NaN
# 152587                      NaN                                   NaN
# 153317                      NaN                                   NaN
# 153820                      NaN                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 772                             NaN               NaN
# 1545                            NaN               NaN
# 2277                            NaN               NaN
# 3018                            NaN               NaN
# 3746                            NaN               NaN
# ...                             ...               ...
# 151693                          NaN               NaN
# 151807                          NaN               NaN
# 152587                          NaN               NaN
# 153317                          NaN               NaN
# 153820                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 772                                         NaN
# 1545                                        NaN
# 2277                                        NaN
# 3018                                        NaN
# 3746                                        NaN
# ...                                         ...
# 151693                                      NaN
# 151807                                      NaN
# 152587                                      NaN
# 153317                                      NaN
# 153820                                      NaN
#
# [221 rows x 67 columns]

# %%
# Rename column 
covid_world = covid_world.rename(columns={'location': 'country'})
covid_world
# Out:
#        iso_code continent            country       date  total_cases  \
# 772         SGP      Asia          Singapore 2022-05-03     819663.0
# 1545        HKG      Asia          Hong Kong 2022-05-03     440609.0
# 2277        GIB    Europe          Gibraltar 2022-05-03      15609.0
# 3018        BHR      Asia            Bahrain 2022-05-03     525171.0
# 3746        MDV      Asia           Maldives 2022-05-03     172270.0
# ...         ...       ...                ...        ...          ...
# 151693      SYR      Asia              Syria 2022-05-03      54963.0
# 151807      TKL   Oceania            Tokelau 2021-12-10          NaN
# 152587      TWN      Asia             Taiwan 2022-05-03      20797.0
# 153317      VAT    Europe            Vatican 2022-05-03         29.0
# 153820      WLF   Oceania  Wallis and Futuna 2022-05-03        454.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 772       16274.0           17573.000        1073.0         6.0
# 1545      37529.0           43093.429        1774.0       220.0
# 2277          NaN                 NaN         101.0         0.0
# 3018       1517.0            2254.429        1458.0         0.0
# 3746        323.0             446.000         297.0         0.0
# ...           ...                 ...           ...         ...
# 151693       69.0              83.286        3092.0         3.0
# 151807        NaN                 NaN           NaN         NaN
# 152587       80.0              60.571         853.0         0.0
# 153317        0.0               0.000           NaN         NaN
# 153820        0.0               0.000           7.0         0.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 772                  10.571  ...             5.2          28.3
# 1545                171.000  ...             NaN           NaN
# 2277                  0.000  ...             NaN           NaN
# 3018                  1.143  ...             5.8          37.6
# 3746                  0.143  ...             2.1          55.0
# ...                     ...  ...             ...           ...
# 151693                3.429  ...             NaN           NaN
# 151807                  NaN  ...             NaN           NaN
# 152587                0.000  ...             NaN           NaN
# 153317                  NaN  ...             NaN           NaN
# 153820                0.000  ...             NaN           NaN
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 772                        NaN                         2.4            83.62
# 1545                       NaN                         NaN            84.86
# 2277                       NaN                         NaN            79.93
# 3018                       NaN                         2.0            77.29
# 3746                    95.803                         NaN            78.92
# ...                        ...                         ...              ...
# 151693                  70.598                         1.5            72.70
# 151807                     NaN                         NaN            81.86
# 152587                     NaN                         NaN            80.46
# 153317                     NaN                         NaN            75.12
# 153820                     NaN                         NaN            79.94
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 772                       0.938                                   NaN
# 1545                      0.949                                   NaN
# 2277                        NaN                                   NaN
# 3018                      0.852                                   NaN
# 3746                      0.740                                   NaN
# ...                         ...                                   ...
# 151693                    0.567                                   NaN
# 151807                      NaN                                   NaN
# 152587                      NaN                                   NaN
# 153317                      NaN                                   NaN
# 153820                      NaN                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 772                             NaN               NaN
# 1545                            NaN               NaN
# 2277                            NaN               NaN
# 3018                            NaN               NaN
# 3746                            NaN               NaN
# ...                             ...               ...
# 151693                          NaN               NaN
# 151807                          NaN               NaN
# 152587                          NaN               NaN
# 153317                          NaN               NaN
# 153820                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 772                                         NaN
# 1545                                        NaN
# 2277                                        NaN
# 3018                                        NaN
# 3746                                        NaN
# ...                                         ...
# 151693                                      NaN
# 151807                                      NaN
# 152587                                      NaN
# 153317                                      NaN
# 153820                                      NaN
#
# [221 rows x 67 columns]

# %%
# Resetting DataFrame index after drop
covid_world = covid_world.reset_index(drop=True)
covid_world
# Out:
#     iso_code continent            country       date  total_cases  new_cases  \
# 0        SGP      Asia          Singapore 2022-05-03     819663.0    16274.0
# 1        HKG      Asia          Hong Kong 2022-05-03     440609.0    37529.0
# 2        GIB    Europe          Gibraltar 2022-05-03      15609.0        NaN
# 3        BHR      Asia            Bahrain 2022-05-03     525171.0     1517.0
# 4        MDV      Asia           Maldives 2022-05-03     172270.0      323.0
# ..       ...       ...                ...        ...          ...        ...
# 216      SYR      Asia              Syria 2022-05-03      54963.0       69.0
# 217      TKL   Oceania            Tokelau 2021-12-10          NaN        NaN
# 218      TWN      Asia             Taiwan 2022-05-03      20797.0       80.0
# 219      VAT    Europe            Vatican 2022-05-03         29.0        0.0
# 220      WLF   Oceania  Wallis and Futuna 2022-05-03        454.0        0.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0             17573.000        1073.0         6.0               10.571  ...
# 1             43093.429        1774.0       220.0              171.000  ...
# 2                   NaN         101.0         0.0                0.000  ...
# 3              2254.429        1458.0         0.0                1.143  ...
# 4               446.000         297.0         0.0                0.143  ...
# ..                  ...           ...         ...                  ...  ...
# 216              83.286        3092.0         3.0                3.429  ...
# 217                 NaN           NaN         NaN                  NaN  ...
# 218              60.571         853.0         0.0                0.000  ...
# 219               0.000           NaN         NaN                  NaN  ...
# 220               0.000           7.0         0.0                0.000  ...
#
#      female_smokers  male_smokers  handwashing_facilities  \
# 0               5.2          28.3                     NaN
# 1               NaN           NaN                     NaN
# 2               NaN           NaN                     NaN
# 3               5.8          37.6                     NaN
# 4               2.1          55.0                  95.803
# ..              ...           ...                     ...
# 216             NaN           NaN                  70.598
# 217             NaN           NaN                     NaN
# 218             NaN           NaN                     NaN
# 219             NaN           NaN                     NaN
# 220             NaN           NaN                     NaN
#
#      hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                           2.4            83.62                    0.938
# 1                           NaN            84.86                    0.949
# 2                           NaN            79.93                      NaN
# 3                           2.0            77.29                    0.852
# 4                           NaN            78.92                    0.740
# ..                          ...              ...                      ...
# 216                         1.5            72.70                    0.567
# 217                         NaN            81.86                      NaN
# 218                         NaN            80.46                      NaN
# 219                         NaN            75.12                      NaN
# 220                         NaN            79.94                      NaN
#
#      excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
# ..                                    ...                          ...
# 216                                   NaN                          NaN
# 217                                   NaN                          NaN
# 218                                   NaN                          NaN
# 219                                   NaN                          NaN
# 220                                   NaN                          NaN
#
#      excess_mortality  excess_mortality_cumulative_per_million
# 0                 NaN                                      NaN
# 1                 NaN                                      NaN
# 2                 NaN                                      NaN
# 3                 NaN                                      NaN
# 4                 NaN                                      NaN
# ..                ...                                      ...
# 216               NaN                                      NaN
# 217               NaN                                      NaN
# 218               NaN                                      NaN
# 219               NaN                                      NaN
# 220               NaN                                      NaN
#
# [221 rows x 67 columns]

# %%
# Getting all column names

list(covid_world.columns.values.tolist())
# Out:
# ['iso_code',
#  'continent',
#  'country',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'new_tests',
#  'total_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'tests_units',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'new_vaccinations',
#  'new_vaccinations_smoothed',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'total_boosters_per_hundred',
#  'new_vaccinations_smoothed_per_million',
#  'new_people_vaccinated_smoothed',
#  'new_people_vaccinated_smoothed_per_hundred',
#  'stringency_index',
#  'population',
#  'population_density',
#  'median_age',
#  'aged_65_older',
#  'aged_70_older',
#  'gdp_per_capita',
#  'extreme_poverty',
#  'cardiovasc_death_rate',
#  'diabetes_prevalence',
#  'female_smokers',
#  'male_smokers',
#  'handwashing_facilities',
#  'hospital_beds_per_thousand',
#  'life_expectancy',
#  'human_development_index',
#  'excess_mortality_cumulative_absolute',
#  'excess_mortality_cumulative',
#  'excess_mortality',
#  'excess_mortality_cumulative_per_million']

# %%
# Filtering columns to keep only the ones needed for analysis

world_filtered = covid_world.filter(['iso_code',
 'continent',
 'country',
 'date',
 'total_cases',
 'total_deaths',                                  
 'total_cases_per_million',
 'total_deaths_per_million',
 'population',
 'population_density',
 'median_age',
 'aged_65_older',
 'aged_70_older',
 'hospital_beds_per_thousand',
 'life_expectancy'])
world_filtered.head(221)
# Out:
#     iso_code continent            country       date  total_cases  \
# 0        SGP      Asia          Singapore 2022-05-03     819663.0
# 1        HKG      Asia          Hong Kong 2022-05-03     440609.0
# 2        GIB    Europe          Gibraltar 2022-05-03      15609.0
# 3        BHR      Asia            Bahrain 2022-05-03     525171.0
# 4        MDV      Asia           Maldives 2022-05-03     172270.0
# ..       ...       ...                ...        ...          ...
# 216      SYR      Asia              Syria 2022-05-03      54963.0
# 217      TKL   Oceania            Tokelau 2021-12-10          NaN
# 218      TWN      Asia             Taiwan 2022-05-03      20797.0
# 219      VAT    Europe            Vatican 2022-05-03         29.0
# 220      WLF   Oceania  Wallis and Futuna 2022-05-03        454.0
#
#      total_deaths  total_cases_per_million  total_deaths_per_million  \
# 0          1073.0               150297.602                   196.751
# 1          1774.0                58337.173                   234.880
# 2           101.0               463298.804                  2997.833
# 3          1458.0               300390.380                   833.955
# 4           297.0               316894.154                   546.338
# ..            ...                      ...                       ...
# 216        3092.0                 3007.435                   169.186
# 217           NaN                      NaN                       NaN
# 218         853.0                  871.809                    35.758
# 219           NaN                35714.286                       NaN
# 220           7.0                40923.021                   630.972
#
#      population  population_density  median_age  aged_65_older  aged_70_older  \
# 0       5453600            7915.731        42.4         12.922          7.049
# 1       7552800            7039.714        44.8         16.303         10.158
# 2         33691            3457.100         NaN            NaN            NaN
# 3       1748295            1935.907        32.4          2.372          1.387
# 4        543620            1454.433        30.6          4.120          2.875
# ..          ...                 ...         ...            ...            ...
# 216    18275704                 NaN        21.7            NaN          2.577
# 217        1368                 NaN         NaN            NaN            NaN
# 218    23855008                 NaN        42.2            NaN          8.353
# 219         812                 NaN         NaN            NaN            NaN
# 220       11094                 NaN         NaN            NaN            NaN
#
#      hospital_beds_per_thousand  life_expectancy
# 0                           2.4            83.62
# 1                           NaN            84.86
# 2                           NaN            79.93
# 3                           2.0            77.29
# 4                           NaN            78.92
# ..                          ...              ...
# 216                         1.5            72.70
# 217                         NaN            81.86
# 218                         NaN            80.46
# 219                         NaN            75.12
# 220                         NaN            79.94
#
# [221 rows x 15 columns]

# %%
# Convert dataset from below link into DataFrame
#  https://www.kaggle.com/datasets/paultimothymooney/latitude-and-longitude-for-every-country-and-state
# Load and Read csv file
load_lat_lng = 'input_data/world_country_and_usa_states_latitude_and_longitude_values.csv'
lat_lng = pd.read_csv(load_lat_lng)
lat_lng_filtered = lat_lng.filter(['latitude', 'longitude', 'country'])
lat_lng_filtered.sort_values('country')
lat_lng_df = lat_lng_filtered.reset_index(drop=True)
lat_lng_df
# Out:
#       latitude  longitude               country
# 0    42.546245   1.601554               Andorra
# 1    23.424076  53.847818  United Arab Emirates
# 2    33.939110  67.709953           Afghanistan
# 3    17.060816 -61.796428   Antigua and Barbuda
# 4    18.220554 -63.068615              Anguilla
# ..         ...        ...                   ...
# 240  15.552727  48.516388                 Yemen
# 241 -12.827500  45.166244               Mayotte
# 242 -30.559482  22.937506          South Africa
# 243 -13.133897  27.849332                Zambia
# 244 -19.015438  29.154857              Zimbabwe
#
# [245 rows x 3 columns]

# %%
# Merging the two dataframes
final_covid = pd.merge(world_filtered, lat_lng_df, on = 'country', how = 'left' )
world_covid = final_covid.reset_index(drop=True)
world_covid
# Out:
#     iso_code continent            country       date  total_cases  \
# 0        SGP      Asia          Singapore 2022-05-03     819663.0
# 1        HKG      Asia          Hong Kong 2022-05-03     440609.0
# 2        GIB    Europe          Gibraltar 2022-05-03      15609.0
# 3        BHR      Asia            Bahrain 2022-05-03     525171.0
# 4        MDV      Asia           Maldives 2022-05-03     172270.0
# ..       ...       ...                ...        ...          ...
# 216      SYR      Asia              Syria 2022-05-03      54963.0
# 217      TKL   Oceania            Tokelau 2021-12-10          NaN
# 218      TWN      Asia             Taiwan 2022-05-03      20797.0
# 219      VAT    Europe            Vatican 2022-05-03         29.0
# 220      WLF   Oceania  Wallis and Futuna 2022-05-03        454.0
#
#      total_deaths  total_cases_per_million  total_deaths_per_million  \
# 0          1073.0               150297.602                   196.751
# 1          1774.0                58337.173                   234.880
# 2           101.0               463298.804                  2997.833
# 3          1458.0               300390.380                   833.955
# 4           297.0               316894.154                   546.338
# ..            ...                      ...                       ...
# 216        3092.0                 3007.435                   169.186
# 217           NaN                      NaN                       NaN
# 218         853.0                  871.809                    35.758
# 219           NaN                35714.286                       NaN
# 220           7.0                40923.021                   630.972
#
#      population  population_density  median_age  aged_65_older  aged_70_older  \
# 0       5453600            7915.731        42.4         12.922          7.049
# 1       7552800            7039.714        44.8         16.303         10.158
# 2         33691            3457.100         NaN            NaN            NaN
# 3       1748295            1935.907        32.4          2.372          1.387
# 4        543620            1454.433        30.6          4.120          2.875
# ..          ...                 ...         ...            ...            ...
# 216    18275704                 NaN        21.7            NaN          2.577
# 217        1368                 NaN         NaN            NaN            NaN
# 218    23855008                 NaN        42.2            NaN          8.353
# 219         812                 NaN         NaN            NaN            NaN
# 220       11094                 NaN         NaN            NaN            NaN
#
#      hospital_beds_per_thousand  life_expectancy   latitude   longitude
# 0                           2.4            83.62   1.352083  103.819836
# 1                           NaN            84.86  22.396428  114.109497
# 2                           NaN            79.93  36.137741   -5.345374
# 3                           2.0            77.29  25.930414   50.637772
# 4                           NaN            78.92   3.202778   73.220680
# ..                          ...              ...        ...         ...
# 216                         1.5            72.70  34.802075   38.996815
# 217                         NaN            81.86  -8.967363 -171.855881
# 218                         NaN            80.46  23.697810  120.960515
# 219                         NaN            75.12        NaN         NaN
# 220                         NaN            79.94 -13.768752 -177.156097
#
# [221 rows x 17 columns]

# %%
# Adding new columns for summary statistical analysis
world_covid['% of World Total Deaths']=''
world_covid['% of World Total Cases']=''
world_covid['% of World Population']=''
world_covid
# Out:
#     iso_code continent            country       date  total_cases  \
# 0        SGP      Asia          Singapore 2022-05-03     819663.0
# 1        HKG      Asia          Hong Kong 2022-05-03     440609.0
# 2        GIB    Europe          Gibraltar 2022-05-03      15609.0
# 3        BHR      Asia            Bahrain 2022-05-03     525171.0
# 4        MDV      Asia           Maldives 2022-05-03     172270.0
# ..       ...       ...                ...        ...          ...
# 216      SYR      Asia              Syria 2022-05-03      54963.0
# 217      TKL   Oceania            Tokelau 2021-12-10          NaN
# 218      TWN      Asia             Taiwan 2022-05-03      20797.0
# 219      VAT    Europe            Vatican 2022-05-03         29.0
# 220      WLF   Oceania  Wallis and Futuna 2022-05-03        454.0
#
#      total_deaths  total_cases_per_million  total_deaths_per_million  \
# 0          1073.0               150297.602                   196.751
# 1          1774.0                58337.173                   234.880
# 2           101.0               463298.804                  2997.833
# 3          1458.0               300390.380                   833.955
# 4           297.0               316894.154                   546.338
# ..            ...                      ...                       ...
# 216        3092.0                 3007.435                   169.186
# 217           NaN                      NaN                       NaN
# 218         853.0                  871.809                    35.758
# 219           NaN                35714.286                       NaN
# 220           7.0                40923.021                   630.972
#
#      population  population_density  median_age  aged_65_older  aged_70_older  \
# 0       5453600            7915.731        42.4         12.922          7.049
# 1       7552800            7039.714        44.8         16.303         10.158
# 2         33691            3457.100         NaN            NaN            NaN
# 3       1748295            1935.907        32.4          2.372          1.387
# 4        543620            1454.433        30.6          4.120          2.875
# ..          ...                 ...         ...            ...            ...
# 216    18275704                 NaN        21.7            NaN          2.577
# 217        1368                 NaN         NaN            NaN            NaN
# 218    23855008                 NaN        42.2            NaN          8.353
# 219         812                 NaN         NaN            NaN            NaN
# 220       11094                 NaN         NaN            NaN            NaN
#
#      hospital_beds_per_thousand  life_expectancy   latitude   longitude  \
# 0                           2.4            83.62   1.352083  103.819836
# 1                           NaN            84.86  22.396428  114.109497
# 2                           NaN            79.93  36.137741   -5.345374
# 3                           2.0            77.29  25.930414   50.637772
# 4                           NaN            78.92   3.202778   73.220680
# ..                          ...              ...        ...         ...
# 216                         1.5            72.70  34.802075   38.996815
# 217                         NaN            81.86  -8.967363 -171.855881
# 218                         NaN            80.46  23.697810  120.960515
# 219                         NaN            75.12        NaN         NaN
# 220                         NaN            79.94 -13.768752 -177.156097
#
#     % of World Total Deaths % of World Total Cases % of World Population
# 0
# 1
# 2
# 3
# 4
# ..                      ...                    ...                   ...
# 216
# 217
# 218
# 219
# 220
#
# [221 rows x 20 columns]

# %%
# Getting Percentages for new columns added
world_covid['% of World Total Deaths']= (world_covid['total_deaths']/world_covid['total_deaths'].sum() * 100).round(3)
world_covid['% of World Total Cases']= (world_covid['total_cases']/world_covid['total_cases'].sum() * 100).round(3)
world_covid['% of World Population']= (world_covid['population']/world_covid['population'].sum() * 100).round(3)

world_covid
# Out:
#     iso_code continent            country       date  total_cases  \
# 0        SGP      Asia          Singapore 2022-05-03     819663.0
# 1        HKG      Asia          Hong Kong 2022-05-03     440609.0
# 2        GIB    Europe          Gibraltar 2022-05-03      15609.0
# 3        BHR      Asia            Bahrain 2022-05-03     525171.0
# 4        MDV      Asia           Maldives 2022-05-03     172270.0
# ..       ...       ...                ...        ...          ...
# 216      SYR      Asia              Syria 2022-05-03      54963.0
# 217      TKL   Oceania            Tokelau 2021-12-10          NaN
# 218      TWN      Asia             Taiwan 2022-05-03      20797.0
# 219      VAT    Europe            Vatican 2022-05-03         29.0
# 220      WLF   Oceania  Wallis and Futuna 2022-05-03        454.0
#
#      total_deaths  total_cases_per_million  total_deaths_per_million  \
# 0          1073.0               150297.602                   196.751
# 1          1774.0                58337.173                   234.880
# 2           101.0               463298.804                  2997.833
# 3          1458.0               300390.380                   833.955
# 4           297.0               316894.154                   546.338
# ..            ...                      ...                       ...
# 216        3092.0                 3007.435                   169.186
# 217           NaN                      NaN                       NaN
# 218         853.0                  871.809                    35.758
# 219           NaN                35714.286                       NaN
# 220           7.0                40923.021                   630.972
#
#      population  population_density  median_age  aged_65_older  aged_70_older  \
# 0       5453600            7915.731        42.4         12.922          7.049
# 1       7552800            7039.714        44.8         16.303         10.158
# 2         33691            3457.100         NaN            NaN            NaN
# 3       1748295            1935.907        32.4          2.372          1.387
# 4        543620            1454.433        30.6          4.120          2.875
# ..          ...                 ...         ...            ...            ...
# 216    18275704                 NaN        21.7            NaN          2.577
# 217        1368                 NaN         NaN            NaN            NaN
# 218    23855008                 NaN        42.2            NaN          8.353
# 219         812                 NaN         NaN            NaN            NaN
# 220       11094                 NaN         NaN            NaN            NaN
#
#      hospital_beds_per_thousand  life_expectancy   latitude   longitude  \
# 0                           2.4            83.62   1.352083  103.819836
# 1                           NaN            84.86  22.396428  114.109497
# 2                           NaN            79.93  36.137741   -5.345374
# 3                           2.0            77.29  25.930414   50.637772
# 4                           NaN            78.92   3.202778   73.220680
# ..                          ...              ...        ...         ...
# 216                         1.5            72.70  34.802075   38.996815
# 217                         NaN            81.86  -8.967363 -171.855881
# 218                         NaN            80.46  23.697810  120.960515
# 219                         NaN            75.12        NaN         NaN
# 220                         NaN            79.94 -13.768752 -177.156097
#
#      % of World Total Deaths  % of World Total Cases  % of World Population
# 0                      0.018                   0.184                  0.070
# 1                      0.030                   0.099                  0.096
# 2                      0.002                   0.004                  0.000
# 3                      0.024                   0.118                  0.022
# 4                      0.005                   0.039                  0.007
# ..                       ...                     ...                    ...
# 216                    0.052                   0.012                  0.233
# 217                      NaN                     NaN                  0.000
# 218                    0.014                   0.005                  0.304
# 219                      NaN                   0.000                  0.000
# 220                    0.000                   0.000                  0.000
#
# [221 rows x 20 columns]

# %%
# Getting the Top 20 Countries with highest total Confirmed Covid Deaths
highest_deaths = world_covid.sort_values(by=['total_deaths'],ascending = False).head(20).reset_index(drop=True)
highest_deaths.to_csv('output_data/highest_deaths.csv', encoding='utf-8', index=False)
highest_deaths
# Out:
#    iso_code      continent         country       date  total_cases  \
# 0       USA  North America   United States 2022-05-03   79265726.0
# 1       BRA  South America          Brazil 2022-05-03   29040800.0
# 2       IND           Asia           India 2022-05-03   42962953.0
# 3       RUS         Europe          Russia 2022-05-03   16619507.0
# 4       MEX  North America          Mexico 2022-05-03    5554392.0
# 5       PER  South America            Peru 2022-05-03    3522484.0
# 6       GBR         Europe  United Kingdom 2022-05-03   19172095.0
# 7       ITA         Europe           Italy 2022-05-03   12990223.0
# 8       IDN           Asia       Indonesia 2022-05-03    5723858.0
# 9       FRA         Europe          France 2022-05-03   23064766.0
# 10      COL  South America        Colombia 2022-05-03    6070616.0
# 11      IRN           Asia            Iran 2022-05-03    7084306.0
# 12      ARG  South America       Argentina 2022-05-03    8934328.0
# 13      DEU         Europe         Germany 2022-05-03   15830112.0
# 14      POL         Europe          Poland 2022-05-03    5734041.0
# 15      UKR         Europe         Ukraine 2022-05-03    5040518.0
# 16      ESP         Europe           Spain 2022-05-03   11100428.0
# 17      ZAF         Africa    South Africa 2022-05-03    3683172.0
# 18      TUR           Asia          Turkey 2022-05-03   14326217.0
# 19      ROU         Europe         Romania 2022-05-03    2765169.0
#
#     total_deaths  total_cases_per_million  total_deaths_per_million  \
# 0       958437.0               238095.936                  2878.923
# 1       652216.0               135708.832                  3047.832
# 2       515036.0                30832.980                   369.623
# 3       348467.0               113900.875                  2388.199
# 4       319604.0                42640.084                  2453.543
# 5       210907.0               105591.900                  6322.263
# 6       162152.0               281086.442                  2377.347
# 7       155782.0               215185.808                  2580.562
# 8       149918.0                20711.467                   542.470
# 9       139312.0               342095.547                  2066.269
# 10      139037.0               118414.443                  2712.079
# 11      137747.0                83316.586                  1620.005
# 12      126708.0               195903.229                  2778.329
# 13      124107.0               188677.272                  1479.217
# 14      112535.0               151706.247                  2977.353
# 15      112459.0               115962.423                  2587.238
# 16      100413.0               237466.636                  2148.092
# 17       99543.0                61343.264                  1657.890
# 18       95379.0               168459.032                  1121.542
# 19       63931.0               144563.047                  3342.313
#
#     population  population_density  median_age  aged_65_older  aged_70_older  \
# 0    332915074              35.608        38.3         15.413          9.732
# 1    213993441              25.040        33.5          8.552          5.060
# 2   1393409033             450.419        28.2          5.989          3.414
# 3    145912022               8.823        39.6         14.178          9.393
# 4    130262220              66.444        29.3          6.857          4.321
# 5     33359415              25.129        29.1          7.151          4.455
# 6     68207114             272.898        40.8         18.517         12.527
# 7     60367471             205.859        47.9         23.021         16.240
# 8    276361788             145.725        29.3          5.319          3.053
# 9     67422000             122.578        42.0         19.718         13.079
# 10    51265841              44.223        32.2          7.646          4.312
# 11    85028760              49.831        32.4          5.440          3.182
# 12    45605823              16.177        31.9         11.198          7.441
# 13    83900471             237.016        46.6         21.453         15.957
# 14    37797000             124.027        41.8         16.763         10.202
# 15    43466822              77.390        41.4         16.462         11.133
# 16    46745211              93.105        45.5         19.436         13.799
# 17    60041996              46.754        27.3          5.344          3.053
# 18    85042736             104.914        31.6          8.153          5.061
# 19    19127772              85.129        43.0         17.850         11.690
#
#     hospital_beds_per_thousand  life_expectancy   latitude   longitude  \
# 0                        2.770            78.86  37.090240  -95.712891
# 1                        2.200            75.88 -14.235004  -51.925280
# 2                        0.530            69.66  20.593684   78.962880
# 3                        8.050            72.58  61.524010  105.318756
# 4                        1.380            75.05  23.634501 -102.552784
# 5                        1.600            76.74  -9.189967  -75.015152
# 6                        2.540            81.32  55.378051   -3.435973
# 7                        3.180            83.51  41.871940   12.567380
# 8                        1.040            71.72  -0.789275  113.921327
# 9                        5.980            82.66  46.227638    2.213749
# 10                       1.710            77.29   4.570868  -74.297333
# 11                       1.500            76.68  32.427908   53.688046
# 12                       5.000            76.67 -38.416097  -63.616672
# 13                       8.000            81.33  51.165691   10.451526
# 14                       6.620            78.73  51.919438   19.145136
# 15                       8.800            72.06  48.379433   31.165580
# 16                       2.970            83.56  40.463667   -3.749220
# 17                       2.320            64.13 -30.559482   22.937506
# 18                       2.810            77.69  38.963745   35.243322
# 19                       6.892            76.05  45.943161   24.966760
#
#     % of World Total Deaths  % of World Total Cases  % of World Population
# 0                    15.995                  17.817                  4.245
# 1                    10.885                   6.528                  2.729
# 2                     8.595                   9.657                 17.767
# 3                     5.815                   3.736                  1.861
# 4                     5.334                   1.248                  1.661
# 5                     3.520                   0.792                  0.425
# 6                     2.706                   4.309                  0.870
# 7                     2.600                   2.920                  0.770
# 8                     2.502                   1.287                  3.524
# 9                     2.325                   5.184                  0.860
# 10                    2.320                   1.365                  0.654
# 11                    2.299                   1.592                  1.084
# 12                    2.115                   2.008                  0.582
# 13                    2.071                   3.558                  1.070
# 14                    1.878                   1.289                  0.482
# 15                    1.877                   1.133                  0.554
# 16                    1.676                   2.495                  0.596
# 17                    1.661                   0.828                  0.766
# 18                    1.592                   3.220                  1.084
# 19                    1.067                   0.622                  0.244

# %%
# Getting the Top 20 Countries with highest total Confirmed Covid Cases
highest_cases = world_covid.sort_values(by=['total_cases'],ascending = False).head(20).reset_index(drop=True)
highest_cases.to_csv('output_data/highest_cases.csv', encoding='utf-8', index=False)
highest_cases
# Out:
#    iso_code      continent         country       date  total_cases  \
# 0       USA  North America   United States 2022-05-03   79265726.0
# 1       IND           Asia           India 2022-05-03   42962953.0
# 2       BRA  South America          Brazil 2022-05-03   29040800.0
# 3       FRA         Europe          France 2022-05-03   23064766.0
# 4       GBR         Europe  United Kingdom 2022-05-03   19172095.0
# 5       RUS         Europe          Russia 2022-05-03   16619507.0
# 6       DEU         Europe         Germany 2022-05-03   15830112.0
# 7       TUR           Asia          Turkey 2022-05-03   14326217.0
# 8       ITA         Europe           Italy 2022-05-03   12990223.0
# 9       ESP         Europe           Spain 2022-05-03   11100428.0
# 10      ARG  South America       Argentina 2022-05-03    8934328.0
# 11      IRN           Asia            Iran 2022-05-03    7084306.0
# 12      NLD         Europe     Netherlands 2022-05-03    6734097.0
# 13      COL  South America        Colombia 2022-05-03    6070616.0
# 14      POL         Europe          Poland 2022-05-03    5734041.0
# 15      IDN           Asia       Indonesia 2022-05-03    5723858.0
# 16      MEX  North America          Mexico 2022-05-03    5554392.0
# 17      JPN           Asia           Japan 2022-05-03    5341246.0
# 18      UKR         Europe         Ukraine 2022-05-03    5040518.0
# 19      KOR           Asia     South Korea 2022-05-03    4456264.0
#
#     total_deaths  total_cases_per_million  total_deaths_per_million  \
# 0       958437.0               238095.936                  2878.923
# 1       515036.0                30832.980                   369.623
# 2       652216.0               135708.832                  3047.832
# 3       139312.0               342095.547                  2066.269
# 4       162152.0               281086.442                  2377.347
# 5       348467.0               113900.875                  2388.199
# 6       124107.0               188677.272                  1479.217
# 7        95379.0               168459.032                  1121.542
# 8       155782.0               215185.808                  2580.562
# 9       100413.0               237466.636                  2148.092
# 10      126708.0               195903.229                  2778.329
# 11      137747.0                83316.586                  1620.005
# 12       21714.0               392130.678                  1264.420
# 13      139037.0               118414.443                  2712.079
# 14      112535.0               151706.247                  2977.353
# 15      149918.0                20711.467                   542.470
# 16      319604.0                42640.084                  2453.543
# 17       24816.0                42373.759                   196.873
# 18      112459.0               115962.423                  2587.238
# 19        8957.0                86857.967                   174.583
#
#     population  population_density  median_age  aged_65_older  aged_70_older  \
# 0    332915074              35.608        38.3         15.413          9.732
# 1   1393409033             450.419        28.2          5.989          3.414
# 2    213993441              25.040        33.5          8.552          5.060
# 3     67422000             122.578        42.0         19.718         13.079
# 4     68207114             272.898        40.8         18.517         12.527
# 5    145912022               8.823        39.6         14.178          9.393
# 6     83900471             237.016        46.6         21.453         15.957
# 7     85042736             104.914        31.6          8.153          5.061
# 8     60367471             205.859        47.9         23.021         16.240
# 9     46745211              93.105        45.5         19.436         13.799
# 10    45605823              16.177        31.9         11.198          7.441
# 11    85028760              49.831        32.4          5.440          3.182
# 12    17173094             508.544        43.2         18.779         11.881
# 13    51265841              44.223        32.2          7.646          4.312
# 14    37797000             124.027        41.8         16.763         10.202
# 15   276361788             145.725        29.3          5.319          3.053
# 16   130262220              66.444        29.3          6.857          4.321
# 17   126050796             347.778        48.2         27.049         18.493
# 18    43466822              77.390        41.4         16.462         11.133
# 19    51305184             527.967        43.4         13.914          8.622
#
#     hospital_beds_per_thousand  life_expectancy   latitude   longitude  \
# 0                         2.77            78.86  37.090240  -95.712891
# 1                         0.53            69.66  20.593684   78.962880
# 2                         2.20            75.88 -14.235004  -51.925280
# 3                         5.98            82.66  46.227638    2.213749
# 4                         2.54            81.32  55.378051   -3.435973
# 5                         8.05            72.58  61.524010  105.318756
# 6                         8.00            81.33  51.165691   10.451526
# 7                         2.81            77.69  38.963745   35.243322
# 8                         3.18            83.51  41.871940   12.567380
# 9                         2.97            83.56  40.463667   -3.749220
# 10                        5.00            76.67 -38.416097  -63.616672
# 11                        1.50            76.68  32.427908   53.688046
# 12                        3.32            82.28  52.132633    5.291266
# 13                        1.71            77.29   4.570868  -74.297333
# 14                        6.62            78.73  51.919438   19.145136
# 15                        1.04            71.72  -0.789275  113.921327
# 16                        1.38            75.05  23.634501 -102.552784
# 17                       13.05            84.63  36.204824  138.252924
# 18                        8.80            72.06  48.379433   31.165580
# 19                       12.27            83.03  35.907757  127.766922
#
#     % of World Total Deaths  % of World Total Cases  % of World Population
# 0                    15.995                  17.817                  4.245
# 1                     8.595                   9.657                 17.767
# 2                    10.885                   6.528                  2.729
# 3                     2.325                   5.184                  0.860
# 4                     2.706                   4.309                  0.870
# 5                     5.815                   3.736                  1.861
# 6                     2.071                   3.558                  1.070
# 7                     1.592                   3.220                  1.084
# 8                     2.600                   2.920                  0.770
# 9                     1.676                   2.495                  0.596
# 10                    2.115                   2.008                  0.582
# 11                    2.299                   1.592                  1.084
# 12                    0.362                   1.514                  0.219
# 13                    2.320                   1.365                  0.654
# 14                    1.878                   1.289                  0.482
# 15                    2.502                   1.287                  3.524
# 16                    5.334                   1.248                  1.661
# 17                    0.414                   1.201                  1.607
# 18                    1.877                   1.133                  0.554
# 19                    0.149                   1.002                  0.654

# %%
# Getting the Top 20 Countries with lowest total Confirmed Covid Cases
lowest_cases = world_covid.sort_values(by=['total_cases'],ascending = True).head(20).reset_index(drop=True)
lowest_cases.to_csv('output_data/lowest_cases.csv', encoding='utf-8', index=False)
lowest_cases
# Out:
#    iso_code      continent                    country       date  total_cases  \
# 0       FSM        Oceania       Micronesia (country) 2022-05-03          1.0
# 1       COK        Oceania               Cook Islands 2022-05-03          2.0
# 2       SHN         Africa               Saint Helena 2022-05-03          4.0
# 3       MHL        Oceania           Marshall Islands 2022-05-03          7.0
# 4       VUT        Oceania                    Vanuatu 2022-05-03         18.0
# 5       VAT         Europe                    Vatican 2022-05-03         29.0
# 6       WSM        Oceania                      Samoa 2022-05-03         33.0
# 7       FLK  South America           Falkland Islands 2022-05-03        115.0
# 8       MSR  North America                 Montserrat 2022-05-03        164.0
# 9       WLF        Oceania          Wallis and Futuna 2022-05-03        454.0
# 10      TON        Oceania                      Tonga 2022-05-03        898.0
# 11      SPM  North America  Saint Pierre and Miquelon 2022-05-03       1102.0
# 12      AIA  North America                   Anguilla 2022-05-03       2555.0
# 13      KIR        Oceania                   Kiribati 2022-05-03       2985.0
# 14      PLW        Oceania                      Palau 2022-05-03       3844.0
# 15      KNA  North America      Saint Kitts and Nevis 2022-05-03       5536.0
# 16      TCA  North America   Turks and Caicos Islands 2022-05-03       5867.0
# 17      STP         Africa      Sao Tome and Principe 2022-05-03       5939.0
# 18      VGB  North America     British Virgin Islands 2022-05-03       6091.0
# 19      TCD         Africa                       Chad 2022-05-03       7257.0
#
#     total_deaths  total_cases_per_million  total_deaths_per_million  \
# 0            NaN                    8.602                       NaN
# 1            NaN                  113.817                       NaN
# 2            NaN                  656.276                       NaN
# 3            NaN                  117.414                       NaN
# 4            1.0                   57.240                     3.180
# 5            NaN                35714.286                       NaN
# 6            NaN                  164.881                       NaN
# 7            NaN                32596.372                       NaN
# 8            2.0                32925.115                   401.526
# 9            7.0                40923.021                   630.972
# 10           NaN                 8411.469                       NaN
# 11           1.0               190954.774                   173.280
# 12           9.0               168925.620                   595.041
# 13          11.0                24590.569                    90.619
# 14           6.0               211510.950                   330.142
# 15          42.0               103387.741                   784.372
# 16          36.0               149569.163                   917.759
# 17          72.0                26588.886                   322.344
# 18          62.0               200210.367                  2037.932
# 19         190.0                  429.028                    11.233
#
#     population  population_density  median_age  aged_65_older  aged_70_older  \
# 0       116255             150.777        23.0          4.810          2.392
# 1        17572                 NaN         NaN            NaN            NaN
# 2         6095                 NaN         NaN            NaN            NaN
# 3        59618             295.150         NaN            NaN            NaN
# 4       314464              22.662        23.1          4.394          2.620
# 5          812                 NaN         NaN            NaN            NaN
# 6       200144              69.413        22.0          5.606          3.564
# 7         3528                 NaN         NaN            NaN            NaN
# 8         4981                 NaN         NaN            NaN            NaN
# 9        11094                 NaN         NaN            NaN            NaN
# 10      106759             150.028        22.3          5.820          4.032
# 11        5771                 NaN         NaN            NaN            NaN
# 12       15125                 NaN         NaN            NaN            NaN
# 13      121388             143.701        23.2          3.895          2.210
# 14       18174              47.237         NaN            NaN            NaN
# 15       53546             212.865         NaN            NaN            NaN
# 16       39226              37.312         NaN            NaN            NaN
# 17      223364             212.841        18.7          2.886          2.162
# 18       30423             207.973         NaN            NaN            NaN
# 19    16914985              11.833        16.7          2.486          1.446
#
#     hospital_beds_per_thousand  life_expectancy   latitude   longitude  \
# 0                          NaN            67.88        NaN         NaN
# 1                          NaN            76.25 -21.236736 -159.777671
# 2                          NaN            80.56 -24.143474  -10.030696
# 3                          2.7            73.70   7.131474  171.184478
# 4                          NaN            70.47 -15.376706  166.959158
# 5                          NaN            75.12        NaN         NaN
# 6                          NaN            73.32 -13.759029 -172.104629
# 7                          NaN            81.44        NaN         NaN
# 8                          NaN            74.16  16.742498  -62.187366
# 9                          NaN            79.94 -13.768752 -177.156097
# 10                         2.6            70.91 -21.178986 -175.198242
# 11                         NaN            81.07  46.941936  -56.271110
# 12                         NaN            81.88  18.220554  -63.068615
# 13                         1.9            68.37  -3.370417 -168.734039
# 14                         4.8            73.70   7.514980  134.582520
# 15                         2.3            76.23  17.357822  -62.782998
# 16                         NaN            80.22  21.694025  -71.797928
# 17                         2.9            70.39        NaN         NaN
# 18                         NaN            79.07  18.420695  -64.639968
# 19                         NaN            54.24  15.454166   18.732207
#
#     % of World Total Deaths  % of World Total Cases  % of World Population
# 0                       NaN                   0.000                  0.001
# 1                       NaN                   0.000                  0.000
# 2                       NaN                   0.000                  0.000
# 3                       NaN                   0.000                  0.001
# 4                     0.000                   0.000                  0.004
# 5                       NaN                   0.000                  0.000
# 6                       NaN                   0.000                  0.003
# 7                       NaN                   0.000                  0.000
# 8                     0.000                   0.000                  0.000
# 9                     0.000                   0.000                  0.000
# 10                      NaN                   0.000                  0.001
# 11                    0.000                   0.000                  0.000
# 12                    0.000                   0.001                  0.000
# 13                    0.000                   0.001                  0.002
# 14                    0.000                   0.001                  0.000
# 15                    0.001                   0.001                  0.001
# 16                    0.001                   0.001                  0.001
# 17                    0.001                   0.001                  0.003
# 18                    0.001                   0.001                  0.000
# 19                    0.003                   0.002                  0.216

# %%
# Getting the Top 20 Countries with lowest total Confirmed Covid Deaths
lowest_deaths = world_covid.sort_values(by=['total_deaths'],ascending = True).head(20).reset_index(drop=True)
lowest_deaths.to_csv('output_data/lowest_deaths.csv', encoding='utf-8', index=False)
lowest_deaths
# Out:
#    iso_code      continent                          country       date  \
# 0       SPM  North America        Saint Pierre and Miquelon 2022-05-03
# 1       VUT        Oceania                          Vanuatu 2022-05-03
# 2       MSR  North America                       Montserrat 2022-05-03
# 3       PLW        Oceania                            Palau 2022-05-03
# 4       WLF        Oceania                Wallis and Futuna 2022-05-03
# 5       BTN           Asia                           Bhutan 2022-05-03
# 6       AIA  North America                         Anguilla 2022-05-03
# 7       KIR        Oceania                         Kiribati 2022-05-03
# 8       CYM  North America                   Cayman Islands 2022-05-03
# 9       GRL  North America                        Greenland 2022-05-03
# 10      FRO         Europe                   Faeroe Islands 2022-05-03
# 11      BES  North America  Bonaire Sint Eustatius and Saba 2022-05-03
# 12      TCA  North America         Turks and Caicos Islands 2022-05-03
# 13      BDI         Africa                          Burundi 2022-05-03
# 14      KNA  North America            Saint Kitts and Nevis 2022-05-03
# 15      DMA  North America                         Dominica 2022-05-03
# 16      VGB  North America           British Virgin Islands 2022-05-03
# 17      NZL        Oceania                      New Zealand 2022-05-03
# 18      ISL         Europe                          Iceland 2022-05-03
# 19      STP         Africa            Sao Tome and Principe 2022-05-03
#
#     total_cases  total_deaths  total_cases_per_million  \
# 0        1102.0           1.0               190954.774
# 1          18.0           1.0                   57.240
# 2         164.0           2.0                32925.115
# 3        3844.0           6.0               211510.950
# 4         454.0           7.0                40923.021
# 5       14451.0           7.0                18529.299
# 6        2555.0           9.0               168925.620
# 7        2985.0          11.0                24590.569
# 8       19373.0          17.0               291332.070
# 9       11806.0          20.0               207603.573
# 10      34658.0          28.0               706541.904
# 11       7616.0          31.0               287993.950
# 12       5867.0          36.0               149569.163
# 13      38150.0          38.0                 3112.906
# 14       5536.0          42.0               103387.741
# 15      11248.0          61.0               155849.914
# 16       6091.0          62.0               200210.367
# 17     222767.0          65.0                43455.709
# 18     140929.0          68.0               382136.814
# 19       5939.0          72.0                26588.886
#
#     total_deaths_per_million  population  population_density  median_age  \
# 0                    173.280        5771                 NaN         NaN
# 1                      3.180      314464              22.662        23.1
# 2                    401.526        4981                 NaN         NaN
# 3                    330.142       18174              47.237         NaN
# 4                    630.972       11094                 NaN         NaN
# 5                      8.976      779900              21.188        28.6
# 6                    595.041       15125                 NaN         NaN
# 7                     90.619      121388             143.701        23.2
# 8                    255.647       66498             256.496         NaN
# 9                    351.692       56868               0.137         NaN
# 10                   570.811       49053              35.308         NaN
# 11                  1172.244       26445                 NaN         NaN
# 12                   917.759       39226              37.312         NaN
# 13                     3.101    12255429             423.062        17.5
# 14                   784.372       53546             212.865         NaN
# 15                   845.203       72172              98.567         NaN
# 16                  2037.932       30423             207.973         NaN
# 17                    12.680     5126300              18.206        37.9
# 18                   184.386      368792               3.404        37.3
# 19                   322.344      223364             212.841        18.7
#
#     aged_65_older  aged_70_older  hospital_beds_per_thousand  life_expectancy  \
# 0             NaN            NaN                         NaN            81.07
# 1           4.394          2.620                         NaN            70.47
# 2             NaN            NaN                         NaN            74.16
# 3             NaN            NaN                        4.80            73.70
# 4             NaN            NaN                         NaN            79.94
# 5           4.885          2.977                        1.70            71.78
# 6             NaN            NaN                         NaN            81.88
# 7           3.895          2.210                        1.90            68.37
# 8             NaN            NaN                         NaN            83.92
# 9             NaN            NaN                         NaN            71.70
# 10            NaN            NaN                         NaN            80.67
# 11            NaN            NaN                         NaN            77.79
# 12            NaN            NaN                         NaN            80.22
# 13          2.562          1.504                        0.80            61.58
# 14            NaN            NaN                        2.30            76.23
# 15            NaN            NaN                        3.80            75.00
# 16            NaN            NaN                         NaN            79.07
# 17         15.322          9.720                        2.61            82.29
# 18         14.431          9.207                        2.91            82.99
# 19          2.886          2.162                        2.90            70.39
#
#      latitude   longitude  % of World Total Deaths  % of World Total Cases  \
# 0   46.941936  -56.271110                    0.000                   0.000
# 1  -15.376706  166.959158                    0.000                   0.000
# 2   16.742498  -62.187366                    0.000                   0.000
# 3    7.514980  134.582520                    0.000                   0.001
# 4  -13.768752 -177.156097                    0.000                   0.000
# 5   27.514162   90.433601                    0.000                   0.003
# 6   18.220554  -63.068615                    0.000                   0.001
# 7   -3.370417 -168.734039                    0.000                   0.001
# 8   19.513469  -80.566956                    0.000                   0.004
# 9   71.706936  -42.604303                    0.000                   0.003
# 10        NaN         NaN                    0.000                   0.008
# 11        NaN         NaN                    0.001                   0.002
# 12  21.694025  -71.797928                    0.001                   0.001
# 13  -3.373056   29.918886                    0.001                   0.009
# 14  17.357822  -62.782998                    0.001                   0.001
# 15  15.414999  -61.370976                    0.001                   0.003
# 16  18.420695  -64.639968                    0.001                   0.001
# 17 -40.900557  174.885971                    0.001                   0.050
# 18  64.963051  -19.020835                    0.001                   0.032
# 19        NaN         NaN                    0.001                   0.001
#
#     % of World Population
# 0                   0.000
# 1                   0.004
# 2                   0.000
# 3                   0.000
# 4                   0.000
# 5                   0.010
# 6                   0.000
# 7                   0.002
# 8                   0.001
# 9                   0.001
# 10                  0.001
# 11                  0.000
# 12                  0.001
# 13                  0.156
# 14                  0.001
# 15                  0.001
# 16                  0.000
# 17                  0.065
# 18                  0.005
# 19                  0.003

# %%
# Grouping Data by Continent
grouped_covid = world_covid.copy().groupby(['continent']).sum()
continent_covid = grouped_covid[['total_cases','total_deaths','population',
                                 '% of World Total Deaths', '% of World Total Cases',
                                 '% of World Population']]
continent_covid = continent_covid.reset_index()
continent_covid
# Out:
#        continent  total_cases  total_deaths  population  \
# 0         Africa   11268386.0      249206.0  1371693397
# 1           Asia  120758338.0     1363608.0  4651957696
# 2         Europe  161014546.0     1721972.0   748850203
# 3  North America   93397289.0     1387009.0   592834824
# 4        Oceania    3831682.0        8037.0    43202462
# 5  South America   54622339.0     1262230.0   433953687
#
#    % of World Total Deaths  % of World Total Cases  % of World Population
# 0                    4.157                   2.535                 17.491
# 1                   22.754                  27.142                 59.316
# 2                   28.737                  36.194                  9.551
# 3                   23.148                  20.993                  7.558
# 4                    0.134                   0.861                  0.551
# 5                   21.065                  12.279                  5.534

# %%
# Saving Continent dataframe to csv file for later plotting
continent_covid.to_csv('output_data/continent_covid.csv', encoding='utf-8', index=False)

# %%
# Saving world Covid dataframe to csv file for later plottting
world_covid.to_csv('output_data/world_covid.csv', encoding='utf-8', index=False)
